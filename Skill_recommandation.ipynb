# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import re
# Load datasets
data = pd.read_csv('Udemy_final_dataset.csv')
data_coursera = pd.read_csv("data_coursera_updated.csv")
data_edx = pd.read_csv("edx_courses.csv")


def clean_numeric_strings(value):
    if isinstance(value, str):
        cleaned_value = re.sub(r'[^\d.]', '', value)
    else:
        cleaned_value = str(value)
    return cleaned_value if cleaned_value else '0'

# Clean the 'rating' column
data['rating'] = data['rating'].apply(clean_numeric_strings)

# Convert the 'rating' column to numeric values, coercing errors to NaN, then to integers
data['rating'] = pd.to_numeric(data['rating'], errors='coerce').fillna(0).astype(int)
data_coursera['features'] = data_coursera['course'] + ' ' + data_coursera['reviewcount'].astype(str) + ' ' + \
                            data_coursera['level']
data_coursera['features'] = data_coursera['features'].fillna('')
vectorizer_coursera = TfidfVectorizer(stop_words='english')
feature_matrix_coursera = vectorizer_coursera.fit_transform(data_coursera['features'])

# Preprocess edX data
text_features = ['title', 'summary', 'instructors', 'Level', 'price', 'course_url']
data_edx['combined_text'] = data_edx[text_features].astype(str).apply(lambda x: ' '.join(x), axis=1)
vectorizer_edx = TfidfVectorizer(stop_words='english')
feature_matrix_edx = vectorizer_edx.fit_transform(data_edx['combined_text'])

# Process Udemy recommendations
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
data['description'] = data['description'].fillna('')
tfidf_matrix = tfidf_vectorizer.fit_transform(data['description'])
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
def get_udemy_recommendations(title, min_rating=0):
    matches = data[data['title'].str.contains(title, case=False)]
    if not matches.empty:
        idx1 = matches.index[0]
        sim_scores = list(enumerate(cosine_sim[idx1]))
        sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
        sim_scores = sim_scores[1:11]
        course_indices = [score[0] for score in sim_scores]
        recommended_courses = data.iloc[course_indices]
        
        # Check if the 'description' column exists and has non-NaN values
        if 'description' in recommended_courses.columns:
            recommended_courses = recommended_courses[
                recommended_courses['description'].notna() &
                recommended_courses['description'].str.contains(title, case=False)
            ]
        
        # Filter based on rating
        if 'rating' in recommended_courses.columns:
            recommended_courses = recommended_courses[
                recommended_courses['rating'] >= min_rating
            ]
    else:
        recommended_courses = None
    
    return recommended_courses



def get_coursera_recommendations(title, min_rating=0, top_n=10):
    # Convert the input title into a feature vector
    input_features_vector = vectorizer_coursera.transform([title])
    
    # Compute cosine similarity between the input feature vector and the feature matrix
    similarity_scores = cosine_similarity(feature_matrix_coursera, input_features_vector)
    
    # Get indices of the top similar courses
    similar_indices = similarity_scores.argsort(axis=0)[-top_n - 1:-1][::-1]
    
    # Fetch the top recommendations from the data_coursera DataFrame
    top_recommendations = data_coursera.iloc[similar_indices.flatten()]
    
    # Check if the 'rating' column exists and has non-NaN values
    if 'rating' in top_recommendations.columns:
        top_recommendations = top_recommendations[top_recommendations['rating'].notna()]
        top_recommendations['rating'] = pd.to_numeric(top_recommendations['rating'], errors='coerce')
        top_recommendations = top_recommendations[top_recommendations['rating'] >= min_rating]
    
    # Sort by rating in descending order
    top_recommendations = top_recommendations.sort_values(by='rating', ascending=False)
    
    return top_recommendations

# Process edX recommendations

def get_edx_recommendations(title, top_n=10):
    # Convert the input title into a feature vector
    input_features_edx_vector = vectorizer_edx.transform([title])
    
    # Compute cosine similarity between the input feature vector and the feature matrix
    similarity_scores_edx = cosine_similarity(feature_matrix_edx, input_features_edx_vector)
    
    # Get indices of the top similar courses
    similar_indices_edx = similarity_scores_edx.argsort(axis=0)[-top_n - 1:-1][::-1]
    
    # Fetch the top recommendations from the data_edx DataFrame
    top_edx = data_edx.iloc[similar_indices_edx.flatten()]
    
    return top_edx

# %%
get_udemy_recommendations('flutter')
# Out:
#                                                   title  \
# 2787  Complete Flutter Guide 2023: Build Android, iO...
# 1997  Dart & Flutter | The Complete Flutter Developm...
# 1384  The Complete Flutter App Development Course fo...
# 3493            The Ultimate Dart & Flutter Course 2023
# 8607  Flutter News Portal App-Firestore Backend(Andr...
# 6768  Flutter 3 with Flutter Projects on Dart Progra...
# 408   Flutter & Dart - The Complete Flutter App Deve...
# 4322  Flutter and Dart | Flutter Dart Programming fr...
# 5302  Flutter ios&Android App With Firebase Backend ...
# 5391  Full Stack Mobile Application Development - Ma...
#
#                                             description  \
# 2787  The Complete Flutter SDK, Flutter Framework & ...
# 1997  2023 Complete Guide To Flutter Development - B...
# 1384  A Complete Guide to the Flutter Framework for ...
# 3493  A Complete Guide / Tutorial to the Flutter & D...
# 8607  Build Flutter ios and Android Apps Using Fires...
# 6768  Flutter Dart course from scratch. Learn Flutte...
# 408   Build Flutter iOS and Android Apps with a Sing...
# 4322  Complete Flutter Dart with Flutter 3 projects ...
# 5302  Build Complete ios & Android app With Flutter ...
# 5391  Native Android,Native IOS,Flutter,React Native...
#
#                                              instructor  rating  reviewcount  \
# 2787                  Sagnik Bhattacharya, Paulina Knop       4        420.0
# 1997  Hussain Mustafa, Codestars • over 2 million st...       4        744.0
# 1384                               Smartherd Developers       4       1263.0
# 3493                                     Rivaan Ranawat       4        293.0
# 8607                                  Yazdani Chowdhury       4         47.0
# 6768                      Oak Academy, OAK Academy Team       4         81.0
# 408   Paulo Dichone | Software Engineer, AWS Cloud P...       4       5252.0
# 4322                      Oak Academy, OAK Academy Team       4        200.0
# 5302                                  Yazdani Chowdhury       3        136.0
# 5391                                      The Apps Firm       3        133.0
#
#               duration      lectures       level  \
# 2787  20.5 total hours  224 lectures  All Levels
# 1997    19 total hours  165 lectures  All Levels
# 1384   4.5 total hours   33 lectures  All Levels
# 3493    44 total hours  332 lectures  All Levels
# 8607   7.5 total hours   39 lectures  All Levels
# 6768    23 total hours  158 lectures  All Levels
# 408     26 total hours  226 lectures  All Levels
# 4322  30.5 total hours  225 lectures  All Levels
# 5302   1.5 total hours   11 lectures  All Levels
# 5391  10.5 total hours   92 lectures    Beginner
#
#                                                     url
# 2787  https://www.udemy.com/courses/search/?q=Comple...
# 1997  https://www.udemy.com/courses/search/?q=Dart &...
# 1384  https://www.udemy.com/courses/search/?q=The Co...
# 3493  https://www.udemy.com/courses/search/?q=The Ul...
# 8607  https://www.udemy.com/courses/search/?q=Flutte...
# 6768  https://www.udemy.com/courses/search/?q=Flutte...
# 408   https://www.udemy.com/courses/search/?q=Flutte...
# 4322  https://www.udemy.com/courses/search/?q=Flutte...
# 5302  https://www.udemy.com/courses/search/?q=Flutte...
# 5391  https://www.udemy.com/courses/search/?q=Full S...

# %%
get_coursera_recommendations('python')
# Out:
#                                       partner  \
# 336                    University of Michigan
# 69                     University of Michigan
# 858                           Rice University
# 361                                       IBM
# 780                    University of Michigan
# 404                                       IBM
# 953                                   Infosec
# 635                University of Pennsylvania
# 815  Pontificia Universidad Católica de Chile
# 201                University of Pennsylvania
#
#                                                 course  \
# 336                                      Python Basics
# 69                                Python 3 Programming
# 858                Introduction to Scripting in Python
# 361                          Data Analysis with Python
# 780                             Statistics with Python
# 404                    Python Project for Data Science
# 953                           Python for Cybersecurity
# 635                 Introduction to Python Programming
# 815  Introducción a la programación en Python I: Ap...
# 201   Introduction to Programming with Python and Java
#
#                                                 skills  rating reviewcount  \
# 336  {" Computer Programming"," Python Programming"...     4.8       16.9k
# 69   {" Python Programming"," Computer Programming"...     4.7       21.3k
# 858  {" Computer Programming"," Programming Princip...     4.7        4.2k
# 361  {" Python Programming"," Data Analysis"," Mach...     4.7       17.3k
# 780  {" General Statistics"," Probability & Statist...     4.6        3.1k
# 404  {" Python Programming"," Computer Programming"...     4.5        3.7k
# 953    {" Python Programming"," Computer Programming"}     4.5         334
# 635  {" Python Programming"," Computer Programming"...     4.5         998
# 815  {" Computational Logic"," Computer Programming...     4.4        4.2k
# 201  {" Computer Programming"," Python Programming"...     4.4        1.5k
#
#              level   certificatetype       duration  crediteligibility  \
# 336      Beginner            Course     1 - 4 Weeks              False
# 69       Beginner    Specialization    3 - 6 Months              False
# 858      Beginner    Specialization    3 - 6 Months              False
# 361      Beginner            Course    1 - 3 Months              False
# 780      Beginner    Specialization    1 - 3 Months              False
# 404  Intermediate            Course     1 - 4 Weeks              False
# 953  Intermediate    Specialization    3 - 6 Months              False
# 635      Beginner            Course     1 - 4 Weeks              False
# 815      Beginner            Course    1 - 3 Months              False
# 201      Beginner    Specialization    3 - 6 Months              False
#
#                                                    url  \
# 336  https://www.coursera.org/search?query=Python B...
# 69   https://www.coursera.org/search?query=Python 3...
# 858  https://www.coursera.org/search?query=Introduc...
# 361  https://www.coursera.org/search?query=Data Ana...
# 780  https://www.coursera.org/search?query=Statisti...
# 404  https://www.coursera.org/search?query=Python P...
# 953  https://www.coursera.org/search?query=Python f...
# 635  https://www.coursera.org/search?query=Introduc...
# 815  https://www.coursera.org/search?query=Introduc...
# 201  https://www.coursera.org/search?query=Introduc...
#
#                                               features
# 336                      Python Basics 16.9k Beginner
# 69                Python 3 Programming 21.3k Beginner
# 858  Introduction to Scripting in Python 4.2k Begin...
# 361          Data Analysis with Python 17.3k Beginner
# 780              Statistics with Python 3.1k Beginner
# 404  Python Project for Data Science 3.7k Intermedi...
# 953         Python for Cybersecurity 334 Intermediate
# 635   Introduction to Python Programming 998 Beginner
# 815  Introducción a la programación en Python I: Ap...
# 201  Introduction to Programming with Python and Ja...

# %%
get_edx_recommendations("html")
# Out:
#                                                  title  \
# 304                      Designing and Creating Skirts
# 332  Introducción a la ciencia de datos y sus aplic...
# 331                               Strategic Management
# 330               Cybersecurity and Privacy in the IoT
# 329                           How to Code: Simple Data
# 328          Agile Leadership Principles and Practices
# 327                             The Ancient Greek Hero
# 326            Android: Introducción a la Programación
# 325                        Anatomy: Human Neuroanatomy
# 324                        Public Financial Management
#
#                                                summary n_enrolled  \
# 304  Learn the construction and style adaptations o...     13,954
# 332  El arte de descubrir las percepciones y tenden...      7,303
# 331     This course is part of a MicroMasters® Program     71,085
# 330  Learn about the security and privacy implicati...     21,440
# 329     This course is part of a MicroMasters® Program     98,113
# 328  Accelerate and improve team decisions by learn...     31,838
# 327  Discover the literature and heroes of ancient ...     51,744
# 326  Desarrollaremos una aplicación de ejemplo, "Mi...     85,786
# 325  Learn about the different parts of the central...     49,319
# 324  What is the government budget cycle? How shoul...     23,288
#
#                              course_type  \
# 304              Self-paced on your time
# 332              Self-paced on your time
# 331              Self-paced on your time
# 330              Self-paced on your time
# 329              Self-paced on your time
# 328              Self-paced on your time
# 327  Instructor-led on a course schedule
# 326              Self-paced on your time
# 325              Self-paced on your time
# 324              Self-paced on your time
#
#                                            institution  \
# 304               The Hong Kong Polytechnic University
# 332                                                IBM
# 331           Indian Institute of Management Bangalore
# 330                                  Curtin University
# 329                     University of British Columbia
# 328  The University of Maryland, College Park-Unive...
# 327                                 Harvard University
# 326                Universitat Politècnica de Valencia
# 325                         The University of Michigan
# 324                    The International Monetary Fund
#
#                                            instructors         Level  \
# 304  Tanya Dove-Kristina Shin-Jalice Cheng-Marco Re...  Introductory
# 332                                        Alex Aklson  Introductory
# 331     P D Jose-Rejie George Pallathita-Sai Yayavaram  Introductory
# 330    Iain Murray AM-Nazanin Mohammadi-Eleanor Sandry  Introductory
# 329                                    Gregor Kiczales  Introductory
# 328                                       John Johnson      Advanced
# 327  Gregory Nagy-Leonard Muellner-Kevin McGrath-Ke...  Introductory
# 326                                Jesús Tomás Gironés  Introductory
# 325                                  Kelli A. Sullivan  Introductory
# 324             Staff of the Fiscal Affairs Department  Intermediate
#
#                         subject language        subtitles  \
# 304                      Design  English          English
# 332  Data Analysis & Statistics  Español          Español
# 331       Business & Management  English  English, हिन्दी
# 330            Computer Science  English          English
# 329            Computer Science  English          English
# 328                 Engineering  English          English
# 327                  Humanities  English          English
# 326            Computer Science  Español          Español
# 325     Biology & Life Sciences  English          English
# 324         Economics & Finance  English          English
#
#            course_effort course_length  \
# 304   3–5 hours per week       5 Weeks
# 332   3–6 hours per week       6 Weeks
# 331   3–5 hours per week       5 Weeks
# 330   4–6 hours per week       5 Weeks
# 329   2–3 hours per week       7 Weeks
# 328   2–3 hours per week       4 Weeks
# 327  8–12 hours per week      18 Weeks
# 326   4–5 hours per week      10 Weeks
# 325   3–4 hours per week       8 Weeks
# 324   4–6 hours per week       8 Weeks
#
#                                             price  \
# 304   FREE-Add a Verified Certificate for $99 USD
# 332   FREE-Add a Verified Certificate for $39 USD
# 331  FREE-Add a Verified Certificate for $150 USD
# 330  FREE-Add a Verified Certificate for $199 USD
# 329  FREE-Add a Verified Certificate for $125 USD
# 328  FREE-Add a Verified Certificate for $199 USD
# 327   FREE-Add a Verified Certificate for $99 USD
# 326   FREE-Add a Verified Certificate for $50 USD
# 325   FREE-Add a Verified Certificate for $49 USD
# 324   FREE-Add a Verified Certificate for $25 USD
#
#                                     course_description  \
# 304  Designing and creating skirts will teach learn...
# 332  Los antiguos egipcios aplicaron datos del cens...
# 331  In this business and management course, you wi...
# 330  As the Internet of Things (IoT) continues to g...
# 329  This programming course takes a unique approac...
# 328  Version 2 of this course series delivers beyon...
# 327  Explore what it means to be human today by stu...
# 326  Android es la plataforma libre desarrollada po...
# 325  In this anatomy course, part of the Anatomy XS...
# 324  This IMFx course is designed to strengthen par...
#
#                                        course_syllabus  \
# 304  _Week 1 – Understand how to record body measur...
# 332                                                NaN
# 331                                                NaN
# 330                                                NaN
# 329                                                NaN
# 328  Week 1: The first week of this course jumps ri...
# 327                                                NaN
# 326                                                NaN
# 325                                                NaN
# 324                                                NaN
#
#                                             course_url  \
# 304  https://www.edx.org/course/designing-and-creat...
# 332  https://www.edx.org/course/Introduccion-a-la-c...
# 331    https://www.edx.org/course/strategic-management
# 330  https://www.edx.org/course/cybersecurity-and-p...
# 329  https://www.edx.org/course/how-to-code-simple-...
# 328  https://www.edx.org/course/agile-leadership-pr...
# 327  https://www.edx.org/course/the-ancient-greek-h...
# 326  https://www.edx.org/course/android-introduccio...
# 325  https://www.edx.org/course/anatomy-human-neuro...
# 324  https://www.edx.org/course/public-financial-ma...
#
#                                          combined_text
# 304  Designing and Creating Skirts Learn the constr...
# 332  Introducción a la ciencia de datos y sus aplic...
# 331  Strategic Management This course is part of a ...
# 330  Cybersecurity and Privacy in the IoT Learn abo...
# 329  How to Code: Simple Data This course is part o...
# 328  Agile Leadership Principles and Practices Acce...
# 327  The Ancient Greek Hero Discover the literature...
# 326  Android: Introducción a la Programación Desarr...
# 325  Anatomy: Human Neuroanatomy Learn about the di...
# 324  Public Financial Management What is the govern...
